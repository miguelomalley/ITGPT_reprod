# %%
import os
import numpy as np
from util import *
import random
import gc
import tensorflow as tf
from tensorflow.keras import layers, models, Model, Input
import copy as c
import pickle
# Out:
# [   INFO   ] MusicExtractorSVM: no classifier models were configured by default
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780656157.802917  342696 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
shuffle = True
seed = 420
batch_size = 1024
steps_per_epoch = 200
nepochs = 500
memlen = 64
mem_size = 5000
narrow_types = 4
train_txt_fp = 'sym/songs/songs_train.txt'
test_txt_fp = 'sym/songs/songs_test.txt'
model_dir = 'trained_models'
load_checkpoint = False
if not os.path.isdir(model_dir):
    os.makedirs(model_dir)

# %%
def generatorify_from_fp_list(dataset_fp_list, memlen = 7, batch_size = 50, mem_size = 50000, shuffle = False, bidirectional_audio = True):
    random.shuffle(dataset_fp_list)
    def _gener():
        k = 0
        hopper = 0
        song = None
        while True:
            while hopper < mem_size:     
                with open(dataset_fp_list[k], 'rb') as f:
                    loaded = pickle.load(f)
                charts, _ = loaded[0], loaded[1]
                del(loaded)
                k = (k + 1) % (len(dataset_fp_list) - 1)
                for chart in charts:
                    newsong = [[a[0] for a in chart], [a[1] for a in chart], [a[1] for a in chart]]
                    newsong[1] = [ddc_string_to_step(b) for b in newsong[1]]
                    newsong[1] = windowize(np.array(newsong[1]), frames=memlen)
                    newsong[0].append(0)
                    newsong[0] = [[newsong[0][i], newsong[0][i+1], 0] for i in range(len(newsong[0])-1)]
                    newsong[0][0][2] = 1
                    newsong[0] = windowize(np.array(newsong[0]), frames = memlen)
                    newsong[0] = np.concatenate((newsong[1],newsong[0]), axis = -1)
                    if song is None:
                        song = newsong
                    else:
                        for j in range(3):
                            song[j] = np.append(song[j],newsong[j], axis = 0)
                    hopper += len(newsong[0])

                if shuffle == True:
                    for i in range(3):
                        np.random.seed(seed)
                        song[i] = np.random.permutation(song[i])
                gc.collect()
            gc.collect()
                
            assert len(song[0])>batch_size+memlen

            success_take = 0
            miss_take = 0
            sd = []
            lb = []
            i = 0
            while success_take<batch_size:
                sd.append(list(song[0][i][:-1])+[[0 for j in range(narrow_types*4)]+list(song[0][i][-1][-3:])])    
                lb.append(sparse_to_categorical(sparceify([int(a) for a in list(song[2][i])]), 255))
                success_take += 1
                i += 1
            sd, lb = np.array(sd), np.array(lb)
            
            for j in range(3):
                song[j] = song[j][int(batch_size + miss_take):]
            hopper -= batch_size
            yield sd, lb
    return _gener()



def get_inputs_and_gens(trn_fp, tst_fp, shuffle = False, batch_size = 1000, bidirectional_audio = True, memlen = 64, aud_memlen = 15):
    trn_ds, tst_ds = get_dataset_fp_list(trn_fp, tst_fp)

    train_gen = generatorify_from_fp_list(trn_ds, batch_size=batch_size, shuffle = shuffle, mem_size=mem_size, memlen=memlen,  bidirectional_audio=bidirectional_audio)
    test_gen = generatorify_from_fp_list(tst_ds, batch_size=batch_size, shuffle = shuffle, mem_size=mem_size, memlen=memlen,  bidirectional_audio=bidirectional_audio)

    inp_shape_1 = (None,memlen+1,19)

    sym_inp = Input(shape = inp_shape_1[1:], batch_size = batch_size)

    return train_gen, test_gen, sym_inp

# %%
train_gen, test_gen, sym_inp = get_inputs_and_gens(train_txt_fp,
                                                      test_txt_fp, 
                                                      shuffle, 
                                                      batch_size=batch_size, 
                                                      memlen=memlen)

sym_proc = layers.LSTM(128, return_sequences = True, dropout = .5)(sym_inp)
sym_proc = layers.LSTM(128, return_sequences = False, dropout = .5)(sym_proc)

output = layers.Dense(256, activation = 'softmax')(sym_proc)

model = Model(sym_inp, output)

model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=1e0),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits = False),
    metrics=[
    tf.keras.metrics.AUC(from_logits = False, curve = 'PR', name = 'auc'),
    tf.keras.metrics.F1Score(average = 'micro'),
    tf.keras.metrics.CategoricalAccuracy()
],
)
print(model.summary())
checkpoint_filepath = os.path.join(model_dir, 'sym_ddc_checkpoint.keras')
if load_checkpoint:
    if os.path.isfile(checkpoint_filepath):
        model.load_weights(checkpoint_filepath)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    verbose = 0,
    save_best_only = True,
    monitor = 'val_auc',
    mode = 'max')

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=10,
    min_lr=1e-6
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc',
    patience=20,
    restore_best_weights=True,
    mode = 'max',
    start_from_epoch = 100
)

model.fit(train_gen, 
          batch_size = batch_size, 
          epochs = nepochs, 
          steps_per_epoch = steps_per_epoch, 
          validation_steps = 20, 
          validation_data = test_gen, 
          callbacks = [model_checkpoint_callback, lr_scheduler, early_stopping])

model.save(model_dir + '/sym_ddc_model.keras')
# Out:
# I0000 00:00:1780656266.272730  342696 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 927 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:05:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1024, 65, 19)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (1024, 65, 128)        │        75,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (1024, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1024, 256)            │        33,024 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 240,384 (939.00 KB)
#  Trainable params: 240,384 (939.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/500
# I0000 00:00:1780656267.719557  342696 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# I0000 00:00:1780656269.123287  343761 cuda_dnn.cc:461] Loaded cuDNN version 90600
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 55s 265ms/step - auc: 0.1969 - categorical_accuracy: 0.2186 - f1_score: 0.2186 - loss: 2.2812 - val_auc: 0.2547 - val_categorical_accuracy: 0.2311 - val_f1_score: 0.2311 - val_loss: 1.9304 - learning_rate: 1.0000
# Epoch 2/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 233ms/step - auc: 0.2176 - categorical_accuracy: 0.2301 - f1_score: 0.2301 - loss: 1.9571 - val_auc: 0.2786 - val_categorical_accuracy: 0.2331 - val_f1_score: 0.2331 - val_loss: 1.6249 - learning_rate: 1.0000
# Epoch 3/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 250ms/step - auc: 0.2093 - categorical_accuracy: 0.2228 - f1_score: 0.2228 - loss: 2.0981 - val_auc: 0.2399 - val_categorical_accuracy: 0.2439 - val_f1_score: 0.2439 - val_loss: 1.7734 - learning_rate: 1.0000
# Epoch 4/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - auc: 0.2064 - categorical_accuracy: 0.2209 - f1_score: 0.2209 - loss: 2.1529 - val_auc: 0.2056 - val_categorical_accuracy: 0.1985 - val_f1_score: 0.1985 - val_loss: 2.3139 - learning_rate: 1.0000
# Epoch 5/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - auc: 0.2264 - categorical_accuracy: 0.2367 - f1_score: 0.2367 - loss: 2.0398 - val_auc: 0.2798 - val_categorical_accuracy: 0.3013 - val_f1_score: 0.3013 - val_loss: 2.0301 - learning_rate: 1.0000
# Epoch 6/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 271ms/step - auc: 0.2345 - categorical_accuracy: 0.2479 - f1_score: 0.2479 - loss: 2.1324 - val_auc: 0.2653 - val_categorical_accuracy: 0.2670 - val_f1_score: 0.2670 - val_loss: 2.0205 - learning_rate: 1.0000
# Epoch 7/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 269ms/step - auc: 0.3577 - categorical_accuracy: 0.3592 - f1_score: 0.3592 - loss: 1.6005 - val_auc: 0.3700 - val_categorical_accuracy: 0.4146 - val_f1_score: 0.4146 - val_loss: 1.8583 - learning_rate: 1.0000
# Epoch 8/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 169ms/step - auc: 0.4874 - categorical_accuracy: 0.4576 - f1_score: 0.4576 - loss: 1.3391 - val_auc: 0.3526 - val_categorical_accuracy: 0.3395 - val_f1_score: 0.3395 - val_loss: 1.7138 - learning_rate: 1.0000
# Epoch 9/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 283ms/step - auc: 0.3636 - categorical_accuracy: 0.3651 - f1_score: 0.3651 - loss: 1.8069 - val_auc: 0.5704 - val_categorical_accuracy: 0.5490 - val_f1_score: 0.5490 - val_loss: 1.1162 - learning_rate: 1.0000
# Epoch 10/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 206ms/step - auc: 0.4061 - categorical_accuracy: 0.4000 - f1_score: 0.4000 - loss: 1.6859 - val_auc: 0.5921 - val_categorical_accuracy: 0.5494 - val_f1_score: 0.5494 - val_loss: 1.0905 - learning_rate: 1.0000
# Epoch 11/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 251ms/step - auc: 0.3949 - categorical_accuracy: 0.3882 - f1_score: 0.3882 - loss: 1.6815 - val_auc: 0.5875 - val_categorical_accuracy: 0.5575 - val_f1_score: 0.5575 - val_loss: 1.0771 - learning_rate: 1.0000
# Epoch 12/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 274ms/step - auc: 0.3948 - categorical_accuracy: 0.3886 - f1_score: 0.3886 - loss: 1.8426 - val_auc: 0.4561 - val_categorical_accuracy: 0.4435 - val_f1_score: 0.4435 - val_loss: 1.6328 - learning_rate: 1.0000
# Epoch 13/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 227ms/step - auc: 0.4243 - categorical_accuracy: 0.4100 - f1_score: 0.4100 - loss: 1.6849 - val_auc: 0.3984 - val_categorical_accuracy: 0.3956 - val_f1_score: 0.3956 - val_loss: 2.0073 - learning_rate: 1.0000
# Epoch 14/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 248ms/step - auc: 0.4059 - categorical_accuracy: 0.3965 - f1_score: 0.3965 - loss: 1.8368 - val_auc: 0.4578 - val_categorical_accuracy: 0.4571 - val_f1_score: 0.4571 - val_loss: 1.5999 - learning_rate: 1.0000
# Epoch 15/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 62s 314ms/step - auc: 0.5542 - categorical_accuracy: 0.5231 - f1_score: 0.5231 - loss: 1.0966 - val_auc: 0.3416 - val_categorical_accuracy: 0.3812 - val_f1_score: 0.3812 - val_loss: 2.0324 - learning_rate: 1.0000
# Epoch 16/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - auc: 0.5517 - categorical_accuracy: 0.4991 - f1_score: 0.4991 - loss: 1.2951 - val_auc: 0.5167 - val_categorical_accuracy: 0.5094 - val_f1_score: 0.5094 - val_loss: 1.3806 - learning_rate: 1.0000
# Epoch 17/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 252ms/step - auc: 0.4300 - categorical_accuracy: 0.4232 - f1_score: 0.4232 - loss: 1.6843 - val_auc: 0.4953 - val_categorical_accuracy: 0.4952 - val_f1_score: 0.4952 - val_loss: 1.4834 - learning_rate: 1.0000
# Epoch 18/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 271ms/step - auc: 0.4575 - categorical_accuracy: 0.4416 - f1_score: 0.4416 - loss: 1.5800 - val_auc: 0.5543 - val_categorical_accuracy: 0.5417 - val_f1_score: 0.5417 - val_loss: 1.2412 - learning_rate: 1.0000
# Epoch 19/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - auc: 0.4372 - categorical_accuracy: 0.4279 - f1_score: 0.4279 - loss: 1.6304 - val_auc: 0.5941 - val_categorical_accuracy: 0.6017 - val_f1_score: 0.6017 - val_loss: 1.1982 - learning_rate: 1.0000
# Epoch 20/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 244ms/step - auc: 0.4535 - categorical_accuracy: 0.4381 - f1_score: 0.4381 - loss: 1.6500 - val_auc: 0.6242 - val_categorical_accuracy: 0.6070 - val_f1_score: 0.6070 - val_loss: 1.0057 - learning_rate: 1.0000
# Epoch 21/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 258ms/step - auc: 0.4418 - categorical_accuracy: 0.4297 - f1_score: 0.4297 - loss: 1.6657 - val_auc: 0.4978 - val_categorical_accuracy: 0.4898 - val_f1_score: 0.4898 - val_loss: 1.5351 - learning_rate: 1.0000
# Epoch 22/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 358ms/step - auc: 0.4580 - categorical_accuracy: 0.4397 - f1_score: 0.4397 - loss: 1.6476 - val_auc: 0.3808 - val_categorical_accuracy: 0.3825 - val_f1_score: 0.3825 - val_loss: 1.9984 - learning_rate: 1.0000
# Epoch 23/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - auc: 0.6348 - categorical_accuracy: 0.5842 - f1_score: 0.5842 - loss: 0.9047 - val_auc: 0.3980 - val_categorical_accuracy: 0.4030 - val_f1_score: 0.4030 - val_loss: 1.6499 - learning_rate: 1.0000
# Epoch 24/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 197ms/step - auc: 0.5186 - categorical_accuracy: 0.4780 - f1_score: 0.4780 - loss: 1.4541 - val_auc: 0.4494 - val_categorical_accuracy: 0.4523 - val_f1_score: 0.4523 - val_loss: 1.6382 - learning_rate: 1.0000
# Epoch 25/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 245ms/step - auc: 0.4822 - categorical_accuracy: 0.4702 - f1_score: 0.4702 - loss: 1.4833 - val_auc: 0.5380 - val_categorical_accuracy: 0.5361 - val_f1_score: 0.5361 - val_loss: 1.2737 - learning_rate: 1.0000
# Epoch 26/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 223ms/step - auc: 0.4628 - categorical_accuracy: 0.4435 - f1_score: 0.4435 - loss: 1.5486 - val_auc: 0.4993 - val_categorical_accuracy: 0.4828 - val_f1_score: 0.4828 - val_loss: 1.4167 - learning_rate: 1.0000
# Epoch 27/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 271ms/step - auc: 0.4598 - categorical_accuracy: 0.4473 - f1_score: 0.4473 - loss: 1.5523 - val_auc: 0.5804 - val_categorical_accuracy: 0.5668 - val_f1_score: 0.5668 - val_loss: 1.1337 - learning_rate: 1.0000
# Epoch 28/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 193ms/step - auc: 0.4804 - categorical_accuracy: 0.4631 - f1_score: 0.4631 - loss: 1.5401 - val_auc: 0.6174 - val_categorical_accuracy: 0.6003 - val_f1_score: 0.6003 - val_loss: 1.0089 - learning_rate: 1.0000
# Epoch 29/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 243ms/step - auc: 0.4533 - categorical_accuracy: 0.4413 - f1_score: 0.4413 - loss: 1.6356 - val_auc: 0.5971 - val_categorical_accuracy: 0.5908 - val_f1_score: 0.5908 - val_loss: 1.1497 - learning_rate: 1.0000
# Epoch 30/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 77s 386ms/step - auc: 0.5016 - categorical_accuracy: 0.4745 - f1_score: 0.4745 - loss: 1.4781 - val_auc: 0.5107 - val_categorical_accuracy: 0.4878 - val_f1_score: 0.4878 - val_loss: 1.4167 - learning_rate: 1.0000
# Epoch 31/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 24s 118ms/step - auc: 0.6803 - categorical_accuracy: 0.6135 - f1_score: 0.6135 - loss: 0.8312 - val_auc: 0.3443 - val_categorical_accuracy: 0.3749 - val_f1_score: 0.3749 - val_loss: 2.0062 - learning_rate: 0.5000
# Epoch 32/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 173ms/step - auc: 0.4716 - categorical_accuracy: 0.4486 - f1_score: 0.4486 - loss: 1.5733 - val_auc: 0.4834 - val_categorical_accuracy: 0.4797 - val_f1_score: 0.4797 - val_loss: 1.5790 - learning_rate: 0.5000
# Epoch 33/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 253ms/step - auc: 0.5090 - categorical_accuracy: 0.4951 - f1_score: 0.4951 - loss: 1.3859 - val_auc: 0.4714 - val_categorical_accuracy: 0.4756 - val_f1_score: 0.4756 - val_loss: 1.5430 - learning_rate: 0.5000
# Epoch 34/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 243ms/step - auc: 0.4632 - categorical_accuracy: 0.4447 - f1_score: 0.4447 - loss: 1.5641 - val_auc: 0.5136 - val_categorical_accuracy: 0.5189 - val_f1_score: 0.5189 - val_loss: 1.3673 - learning_rate: 0.5000
# Epoch 35/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 242ms/step - auc: 0.4718 - categorical_accuracy: 0.4540 - f1_score: 0.4540 - loss: 1.5283 - val_auc: 0.5124 - val_categorical_accuracy: 0.5060 - val_f1_score: 0.5060 - val_loss: 1.4574 - learning_rate: 0.5000
# Epoch 36/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 217ms/step - auc: 0.4902 - categorical_accuracy: 0.4725 - f1_score: 0.4725 - loss: 1.4985 - val_auc: 0.5859 - val_categorical_accuracy: 0.5910 - val_f1_score: 0.5910 - val_loss: 1.1745 - learning_rate: 0.5000
# Epoch 37/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 249ms/step - auc: 0.4506 - categorical_accuracy: 0.4373 - f1_score: 0.4373 - loss: 1.6729 - val_auc: 0.6140 - val_categorical_accuracy: 0.6057 - val_f1_score: 0.6057 - val_loss: 1.0452 - learning_rate: 0.5000
# Epoch 38/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 319ms/step - auc: 0.5593 - categorical_accuracy: 0.5209 - f1_score: 0.5209 - loss: 1.2579 - val_auc: 0.6221 - val_categorical_accuracy: 0.6073 - val_f1_score: 0.6073 - val_loss: 0.9745 - learning_rate: 0.5000
# Epoch 39/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 141ms/step - auc: 0.6575 - categorical_accuracy: 0.5824 - f1_score: 0.5824 - loss: 0.9837 - val_auc: 0.4867 - val_categorical_accuracy: 0.4709 - val_f1_score: 0.4709 - val_loss: 1.5827 - learning_rate: 0.5000
# Epoch 40/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 255ms/step - auc: 0.4840 - categorical_accuracy: 0.4663 - f1_score: 0.4663 - loss: 1.5219 - val_auc: 0.4540 - val_categorical_accuracy: 0.4629 - val_f1_score: 0.4629 - val_loss: 1.7116 - learning_rate: 0.5000
# Epoch 41/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - auc: 0.4981 - categorical_accuracy: 0.4833 - f1_score: 0.4833 - loss: 1.4081 - val_auc: 0.4829 - val_categorical_accuracy: 0.4719 - val_f1_score: 0.4719 - val_loss: 1.5081 - learning_rate: 0.5000
# Epoch 42/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 229ms/step - auc: 0.4622 - categorical_accuracy: 0.4438 - f1_score: 0.4438 - loss: 1.5441 - val_auc: 0.5086 - val_categorical_accuracy: 0.5062 - val_f1_score: 0.5062 - val_loss: 1.4189 - learning_rate: 0.5000
# Epoch 43/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 250ms/step - auc: 0.4760 - categorical_accuracy: 0.4578 - f1_score: 0.4578 - loss: 1.5598 - val_auc: 0.5075 - val_categorical_accuracy: 0.5159 - val_f1_score: 0.5159 - val_loss: 1.3486 - learning_rate: 0.5000
# Epoch 44/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 217ms/step - auc: 0.4884 - categorical_accuracy: 0.4712 - f1_score: 0.4712 - loss: 1.4924 - val_auc: 0.5009 - val_categorical_accuracy: 0.5088 - val_f1_score: 0.5088 - val_loss: 1.4818 - learning_rate: 0.5000
# Epoch 45/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 241ms/step - auc: 0.4742 - categorical_accuracy: 0.4563 - f1_score: 0.4563 - loss: 1.6006 - val_auc: 0.6116 - val_categorical_accuracy: 0.6015 - val_f1_score: 0.6015 - val_loss: 1.0156 - learning_rate: 0.5000
# Epoch 46/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 319ms/step - auc: 0.5975 - categorical_accuracy: 0.5505 - f1_score: 0.5505 - loss: 1.1283 - val_auc: 0.6330 - val_categorical_accuracy: 0.6099 - val_f1_score: 0.6099 - val_loss: 0.9171 - learning_rate: 0.5000
# Epoch 47/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - auc: 0.6397 - categorical_accuracy: 0.5655 - f1_score: 0.5655 - loss: 1.0501 - val_auc: 0.6114 - val_categorical_accuracy: 0.5837 - val_f1_score: 0.5837 - val_loss: 0.9977 - learning_rate: 0.5000
# Epoch 48/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 281ms/step - auc: 0.4822 - categorical_accuracy: 0.4677 - f1_score: 0.4677 - loss: 1.5152 - val_auc: 0.4519 - val_categorical_accuracy: 0.4471 - val_f1_score: 0.4471 - val_loss: 1.6840 - learning_rate: 0.5000
# Epoch 49/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 222ms/step - auc: 0.5041 - categorical_accuracy: 0.4839 - f1_score: 0.4839 - loss: 1.4312 - val_auc: 0.4566 - val_categorical_accuracy: 0.4584 - val_f1_score: 0.4584 - val_loss: 1.6805 - learning_rate: 0.5000
# Epoch 50/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 254ms/step - auc: 0.4796 - categorical_accuracy: 0.4619 - f1_score: 0.4619 - loss: 1.4679 - val_auc: 0.4815 - val_categorical_accuracy: 0.4718 - val_f1_score: 0.4718 - val_loss: 1.4821 - learning_rate: 0.5000
# Epoch 51/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 247ms/step - auc: 0.4692 - categorical_accuracy: 0.4519 - f1_score: 0.4519 - loss: 1.6044 - val_auc: 0.5057 - val_categorical_accuracy: 0.5146 - val_f1_score: 0.5146 - val_loss: 1.4136 - learning_rate: 0.5000
# Epoch 52/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 223ms/step - auc: 0.4904 - categorical_accuracy: 0.4700 - f1_score: 0.4700 - loss: 1.4812 - val_auc: 0.5107 - val_categorical_accuracy: 0.5178 - val_f1_score: 0.5178 - val_loss: 1.3929 - learning_rate: 0.5000
# Epoch 53/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 60s 301ms/step - auc: 0.4753 - categorical_accuracy: 0.4547 - f1_score: 0.4547 - loss: 1.6035 - val_auc: 0.5223 - val_categorical_accuracy: 0.5252 - val_f1_score: 0.5252 - val_loss: 1.3642 - learning_rate: 0.5000
# Epoch 54/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 215ms/step - auc: 0.4163 - categorical_accuracy: 0.3577 - f1_score: 0.3577 - loss: 1.3945 - val_auc: 0.5934 - val_categorical_accuracy: 0.5903 - val_f1_score: 0.5903 - val_loss: 1.0261 - learning_rate: 0.5000
# Epoch 55/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - auc: 0.5925 - categorical_accuracy: 0.5346 - f1_score: 0.5346 - loss: 1.2150 - val_auc: 0.6073 - val_categorical_accuracy: 0.5984 - val_f1_score: 0.5984 - val_loss: 1.0558 - learning_rate: 0.5000
# Epoch 56/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 244ms/step - auc: 0.4859 - categorical_accuracy: 0.4710 - f1_score: 0.4710 - loss: 1.4898 - val_auc: 0.5439 - val_categorical_accuracy: 0.5331 - val_f1_score: 0.5331 - val_loss: 1.3026 - learning_rate: 0.5000
# Epoch 57/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 264ms/step - auc: 0.4963 - categorical_accuracy: 0.4757 - f1_score: 0.4757 - loss: 1.4569 - val_auc: 0.3999 - val_categorical_accuracy: 0.4075 - val_f1_score: 0.4075 - val_loss: 1.9327 - learning_rate: 0.2500
# Epoch 58/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 219ms/step - auc: 0.4751 - categorical_accuracy: 0.4573 - f1_score: 0.4573 - loss: 1.5036 - val_auc: 0.4809 - val_categorical_accuracy: 0.4889 - val_f1_score: 0.4889 - val_loss: 1.6265 - learning_rate: 0.2500
# Epoch 59/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 249ms/step - auc: 0.4963 - categorical_accuracy: 0.4735 - f1_score: 0.4735 - loss: 1.5072 - val_auc: 0.4606 - val_categorical_accuracy: 0.4692 - val_f1_score: 0.4692 - val_loss: 1.6528 - learning_rate: 0.2500
# Epoch 60/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 228ms/step - auc: 0.4732 - categorical_accuracy: 0.4585 - f1_score: 0.4585 - loss: 1.5441 - val_auc: 0.5334 - val_categorical_accuracy: 0.5337 - val_f1_score: 0.5337 - val_loss: 1.3729 - learning_rate: 0.2500
# Epoch 61/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 357ms/step - auc: 0.5026 - categorical_accuracy: 0.4740 - f1_score: 0.4740 - loss: 1.5038 - val_auc: 0.5170 - val_categorical_accuracy: 0.5282 - val_f1_score: 0.5282 - val_loss: 1.3686 - learning_rate: 0.2500
# Epoch 62/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 212ms/step - auc: 0.6836 - categorical_accuracy: 0.6152 - f1_score: 0.6152 - loss: 0.8355 - val_auc: 0.5814 - val_categorical_accuracy: 0.5605 - val_f1_score: 0.5605 - val_loss: 1.1273 - learning_rate: 0.2500
# Epoch 63/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - auc: 0.5446 - categorical_accuracy: 0.4980 - f1_score: 0.4980 - loss: 1.3767 - val_auc: 0.5863 - val_categorical_accuracy: 0.6014 - val_f1_score: 0.6014 - val_loss: 1.1649 - learning_rate: 0.2500
# Epoch 64/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 241ms/step - auc: 0.5126 - categorical_accuracy: 0.4971 - f1_score: 0.4971 - loss: 1.3913 - val_auc: 0.6013 - val_categorical_accuracy: 0.6040 - val_f1_score: 0.6040 - val_loss: 1.0687 - learning_rate: 0.2500
# Epoch 65/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 241ms/step - auc: 0.4864 - categorical_accuracy: 0.4620 - f1_score: 0.4620 - loss: 1.4859 - val_auc: 0.5320 - val_categorical_accuracy: 0.5308 - val_f1_score: 0.5308 - val_loss: 1.3720 - learning_rate: 0.2500
# Epoch 66/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 268ms/step - auc: 0.4688 - categorical_accuracy: 0.4500 - f1_score: 0.4500 - loss: 1.5291 - val_auc: 0.3974 - val_categorical_accuracy: 0.4073 - val_f1_score: 0.4073 - val_loss: 1.9689 - learning_rate: 0.2500
# Epoch 67/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 228ms/step - auc: 0.5014 - categorical_accuracy: 0.4802 - f1_score: 0.4802 - loss: 1.4712 - val_auc: 0.4685 - val_categorical_accuracy: 0.4924 - val_f1_score: 0.4924 - val_loss: 1.7006 - learning_rate: 0.1250
# Epoch 68/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 250ms/step - auc: 0.4753 - categorical_accuracy: 0.4578 - f1_score: 0.4578 - loss: 1.5687 - val_auc: 0.4421 - val_categorical_accuracy: 0.4632 - val_f1_score: 0.4632 - val_loss: 1.7516 - learning_rate: 0.1250
# Epoch 69/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 74s 373ms/step - auc: 0.5297 - categorical_accuracy: 0.4945 - f1_score: 0.4945 - loss: 1.4033 - val_auc: 0.5287 - val_categorical_accuracy: 0.5272 - val_f1_score: 0.5272 - val_loss: 1.3726 - learning_rate: 0.1250
# Epoch 70/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - auc: 0.6976 - categorical_accuracy: 0.6198 - f1_score: 0.6198 - loss: 0.8189 - val_auc: 0.5070 - val_categorical_accuracy: 0.5167 - val_f1_score: 0.5167 - val_loss: 1.4488 - learning_rate: 0.1250
# Epoch 71/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 240ms/step - auc: 0.4836 - categorical_accuracy: 0.4627 - f1_score: 0.4627 - loss: 1.5316 - val_auc: 0.4792 - val_categorical_accuracy: 0.5050 - val_f1_score: 0.5050 - val_loss: 1.6522 - learning_rate: 0.1250
# Epoch 72/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 200ms/step - auc: 0.5277 - categorical_accuracy: 0.5109 - f1_score: 0.5109 - loss: 1.3273 - val_auc: 0.5889 - val_categorical_accuracy: 0.6008 - val_f1_score: 0.6008 - val_loss: 1.1861 - learning_rate: 0.1250
# Epoch 73/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - auc: 0.4784 - categorical_accuracy: 0.4565 - f1_score: 0.4565 - loss: 1.5142 - val_auc: 0.5468 - val_categorical_accuracy: 0.5839 - val_f1_score: 0.5839 - val_loss: 1.4074 - learning_rate: 0.1250
# Epoch 74/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 259ms/step - auc: 0.4853 - categorical_accuracy: 0.4654 - f1_score: 0.4654 - loss: 1.4991 - val_auc: 0.5185 - val_categorical_accuracy: 0.5101 - val_f1_score: 0.5101 - val_loss: 1.4568 - learning_rate: 0.1250
# Epoch 75/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 231ms/step - auc: 0.5016 - categorical_accuracy: 0.4835 - f1_score: 0.4835 - loss: 1.4581 - val_auc: 0.3743 - val_categorical_accuracy: 0.3983 - val_f1_score: 0.3983 - val_loss: 2.0753 - learning_rate: 0.1250
# Epoch 76/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 249ms/step - auc: 0.4641 - categorical_accuracy: 0.4482 - f1_score: 0.4482 - loss: 1.6271 - val_auc: 0.4722 - val_categorical_accuracy: 0.4983 - val_f1_score: 0.4983 - val_loss: 1.7246 - learning_rate: 0.1250
# Epoch 77/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 349ms/step - auc: 0.5763 - categorical_accuracy: 0.5344 - f1_score: 0.5344 - loss: 1.2115 - val_auc: 0.4257 - val_categorical_accuracy: 0.4442 - val_f1_score: 0.4442 - val_loss: 1.7985 - learning_rate: 0.0625
# Epoch 78/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 95ms/step - auc: 0.6616 - categorical_accuracy: 0.5836 - f1_score: 0.5836 - loss: 0.9825 - val_auc: 0.4532 - val_categorical_accuracy: 0.4766 - val_f1_score: 0.4766 - val_loss: 1.7262 - learning_rate: 0.0625
# Epoch 79/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - auc: 0.4985 - categorical_accuracy: 0.4801 - f1_score: 0.4801 - loss: 1.4804 - val_auc: 0.4718 - val_categorical_accuracy: 0.4993 - val_f1_score: 0.4993 - val_loss: 1.5922 - learning_rate: 0.0625
# Epoch 80/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 260ms/step - auc: 0.5205 - categorical_accuracy: 0.5023 - f1_score: 0.5023 - loss: 1.3442 - val_auc: 0.4955 - val_categorical_accuracy: 0.5068 - val_f1_score: 0.5068 - val_loss: 1.5546 - learning_rate: 0.0625
# Epoch 81/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 191ms/step - auc: 0.4727 - categorical_accuracy: 0.4511 - f1_score: 0.4511 - loss: 1.5072 - val_auc: 0.5593 - val_categorical_accuracy: 0.5830 - val_f1_score: 0.5830 - val_loss: 1.3210 - learning_rate: 0.0625
# Epoch 82/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 241ms/step - auc: 0.4812 - categorical_accuracy: 0.4615 - f1_score: 0.4615 - loss: 1.5526 - val_auc: 0.5670 - val_categorical_accuracy: 0.5879 - val_f1_score: 0.5879 - val_loss: 1.3208 - learning_rate: 0.0625
# Epoch 83/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 227ms/step - auc: 0.4981 - categorical_accuracy: 0.4800 - f1_score: 0.4800 - loss: 1.4555 - val_auc: 0.5160 - val_categorical_accuracy: 0.5337 - val_f1_score: 0.5337 - val_loss: 1.5437 - learning_rate: 0.0625
# Epoch 84/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 260ms/step - auc: 0.4876 - categorical_accuracy: 0.4667 - f1_score: 0.4667 - loss: 1.5603 - val_auc: 0.3757 - val_categorical_accuracy: 0.3982 - val_f1_score: 0.3982 - val_loss: 2.0216 - learning_rate: 0.0625
# Epoch 85/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 61s 308ms/step - auc: 0.6111 - categorical_accuracy: 0.5593 - f1_score: 0.5593 - loss: 1.0912 - val_auc: 0.4875 - val_categorical_accuracy: 0.4963 - val_f1_score: 0.4963 - val_loss: 1.6070 - learning_rate: 0.0625
# Epoch 86/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - auc: 0.6404 - categorical_accuracy: 0.5659 - f1_score: 0.5659 - loss: 1.0530 - val_auc: 0.4276 - val_categorical_accuracy: 0.4522 - val_f1_score: 0.4522 - val_loss: 1.8249 - learning_rate: 0.0625
# Epoch 87/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 231ms/step - auc: 0.4873 - categorical_accuracy: 0.4743 - f1_score: 0.4743 - loss: 1.5014 - val_auc: 0.4679 - val_categorical_accuracy: 0.4902 - val_f1_score: 0.4902 - val_loss: 1.6576 - learning_rate: 0.0312
# Epoch 88/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - auc: 0.5111 - categorical_accuracy: 0.4890 - f1_score: 0.4890 - loss: 1.4130 - val_auc: 0.4662 - val_categorical_accuracy: 0.4945 - val_f1_score: 0.4945 - val_loss: 1.6135 - learning_rate: 0.0312
# Epoch 89/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 272ms/step - auc: 0.4834 - categorical_accuracy: 0.4647 - f1_score: 0.4647 - loss: 1.4674 - val_auc: 0.4861 - val_categorical_accuracy: 0.4981 - val_f1_score: 0.4981 - val_loss: 1.5565 - learning_rate: 0.0312
# Epoch 90/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 201ms/step - auc: 0.4775 - categorical_accuracy: 0.4600 - f1_score: 0.4600 - loss: 1.5733 - val_auc: 0.5708 - val_categorical_accuracy: 0.5893 - val_f1_score: 0.5893 - val_loss: 1.2571 - learning_rate: 0.0312
# Epoch 91/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 222ms/step - auc: 0.4917 - categorical_accuracy: 0.4698 - f1_score: 0.4698 - loss: 1.4879 - val_auc: 0.5597 - val_categorical_accuracy: 0.5847 - val_f1_score: 0.5847 - val_loss: 1.3578 - learning_rate: 0.0312
# Epoch 92/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 249ms/step - auc: 0.4803 - categorical_accuracy: 0.4581 - f1_score: 0.4581 - loss: 1.5871 - val_auc: 0.5080 - val_categorical_accuracy: 0.5149 - val_f1_score: 0.5149 - val_loss: 1.5385 - learning_rate: 0.0312
# Epoch 93/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - auc: 0.6680 - categorical_accuracy: 0.6083 - f1_score: 0.6083 - loss: 0.8790 - val_auc: 0.4058 - val_categorical_accuracy: 0.4144 - val_f1_score: 0.4144 - val_loss: 1.8852 - learning_rate: 0.0312
# Epoch 94/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 153ms/step - auc: 0.5959 - categorical_accuracy: 0.5358 - f1_score: 0.5358 - loss: 1.2110 - val_auc: 0.4460 - val_categorical_accuracy: 0.4767 - val_f1_score: 0.4767 - val_loss: 1.8342 - learning_rate: 0.0312
# Epoch 95/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - auc: 0.4937 - categorical_accuracy: 0.4802 - f1_score: 0.4802 - loss: 1.4569 - val_auc: 0.4154 - val_categorical_accuracy: 0.4383 - val_f1_score: 0.4383 - val_loss: 1.8584 - learning_rate: 0.0312
# Epoch 96/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 243ms/step - auc: 0.5021 - categorical_accuracy: 0.4791 - f1_score: 0.4791 - loss: 1.4473 - val_auc: 0.4752 - val_categorical_accuracy: 0.4892 - val_f1_score: 0.4892 - val_loss: 1.6332 - learning_rate: 0.0312
# Epoch 97/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 230ms/step - auc: 0.4768 - categorical_accuracy: 0.4600 - f1_score: 0.4600 - loss: 1.4979 - val_auc: 0.4642 - val_categorical_accuracy: 0.4911 - val_f1_score: 0.4911 - val_loss: 1.6182 - learning_rate: 0.0156
# Epoch 98/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 55s 278ms/step - auc: 0.4992 - categorical_accuracy: 0.4775 - f1_score: 0.4775 - loss: 1.5033 - val_auc: 0.5028 - val_categorical_accuracy: 0.5137 - val_f1_score: 0.5137 - val_loss: 1.5395 - learning_rate: 0.0156
# Epoch 99/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 37s 187ms/step - auc: 0.4766 - categorical_accuracy: 0.4591 - f1_score: 0.4591 - loss: 1.5391 - val_auc: 0.5663 - val_categorical_accuracy: 0.5892 - val_f1_score: 0.5892 - val_loss: 1.2876 - learning_rate: 0.0156
# Epoch 100/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 321ms/step - auc: 0.5079 - categorical_accuracy: 0.4785 - f1_score: 0.4785 - loss: 1.4812 - val_auc: 0.5848 - val_categorical_accuracy: 0.5964 - val_f1_score: 0.5964 - val_loss: 1.2290 - learning_rate: 0.0156
# Epoch 101/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 173ms/step - auc: 0.6863 - categorical_accuracy: 0.6195 - f1_score: 0.6195 - loss: 0.8296 - val_auc: 0.5560 - val_categorical_accuracy: 0.5498 - val_f1_score: 0.5498 - val_loss: 1.2779 - learning_rate: 0.0156
# Epoch 102/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 201ms/step - auc: 0.5366 - categorical_accuracy: 0.4944 - f1_score: 0.4944 - loss: 1.3933 - val_auc: 0.3646 - val_categorical_accuracy: 0.3869 - val_f1_score: 0.3869 - val_loss: 2.0525 - learning_rate: 0.0156
# Epoch 103/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - auc: 0.5181 - categorical_accuracy: 0.5038 - f1_score: 0.5038 - loss: 1.3816 - val_auc: 0.4623 - val_categorical_accuracy: 0.4886 - val_f1_score: 0.4886 - val_loss: 1.7413 - learning_rate: 0.0156
# Epoch 104/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 239ms/step - auc: 0.4866 - categorical_accuracy: 0.4637 - f1_score: 0.4637 - loss: 1.4886 - val_auc: 0.4045 - val_categorical_accuracy: 0.4291 - val_f1_score: 0.4291 - val_loss: 1.9000 - learning_rate: 0.0156
# Epoch 105/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 239ms/step - auc: 0.4792 - categorical_accuracy: 0.4607 - f1_score: 0.4607 - loss: 1.4998 - val_auc: 0.4968 - val_categorical_accuracy: 0.5123 - val_f1_score: 0.5123 - val_loss: 1.5531 - learning_rate: 0.0156
# Epoch 106/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - auc: 0.5068 - categorical_accuracy: 0.4844 - f1_score: 0.4844 - loss: 1.4537 - val_auc: 0.4731 - val_categorical_accuracy: 0.4957 - val_f1_score: 0.4957 - val_loss: 1.6122 - learning_rate: 0.0156
# Epoch 107/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 263ms/step - auc: 0.4754 - categorical_accuracy: 0.4579 - f1_score: 0.4579 - loss: 1.5690 - val_auc: 0.5119 - val_categorical_accuracy: 0.5310 - val_f1_score: 0.5310 - val_loss: 1.5029 - learning_rate: 0.0078
# Epoch 108/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - auc: 0.5389 - categorical_accuracy: 0.5026 - f1_score: 0.5026 - loss: 1.3790 - val_auc: 0.5789 - val_categorical_accuracy: 0.5923 - val_f1_score: 0.5923 - val_loss: 1.2415 - learning_rate: 0.0078
# Epoch 109/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 177ms/step - auc: 0.6876 - categorical_accuracy: 0.6134 - f1_score: 0.6134 - loss: 0.8566 - val_auc: 0.5921 - val_categorical_accuracy: 0.5986 - val_f1_score: 0.5986 - val_loss: 1.1552 - learning_rate: 0.0078
# Epoch 110/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 231ms/step - auc: 0.4835 - categorical_accuracy: 0.4643 - f1_score: 0.4643 - loss: 1.5254 - val_auc: 0.5055 - val_categorical_accuracy: 0.5132 - val_f1_score: 0.5132 - val_loss: 1.5186 - learning_rate: 0.0078
# Epoch 111/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 259ms/step - auc: 0.5291 - categorical_accuracy: 0.5134 - f1_score: 0.5134 - loss: 1.3188 - val_auc: 0.3699 - val_categorical_accuracy: 0.3930 - val_f1_score: 0.3930 - val_loss: 2.0604 - learning_rate: 0.0078
# Epoch 112/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 215ms/step - auc: 0.4761 - categorical_accuracy: 0.4546 - f1_score: 0.4546 - loss: 1.5174 - val_auc: 0.4343 - val_categorical_accuracy: 0.4663 - val_f1_score: 0.4663 - val_loss: 1.8503 - learning_rate: 0.0078
# Epoch 113/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 50s 253ms/step - auc: 0.4873 - categorical_accuracy: 0.4682 - f1_score: 0.4682 - loss: 1.5074 - val_auc: 0.4015 - val_categorical_accuracy: 0.4268 - val_f1_score: 0.4268 - val_loss: 1.9212 - learning_rate: 0.0078
# Epoch 114/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 218ms/step - auc: 0.5009 - categorical_accuracy: 0.4797 - f1_score: 0.4797 - loss: 1.4593 - val_auc: 0.4930 - val_categorical_accuracy: 0.5093 - val_f1_score: 0.5093 - val_loss: 1.5720 - learning_rate: 0.0078
# Epoch 115/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 254ms/step - auc: 0.4624 - categorical_accuracy: 0.4481 - f1_score: 0.4481 - loss: 1.6370 - val_auc: 0.4509 - val_categorical_accuracy: 0.4804 - val_f1_score: 0.4804 - val_loss: 1.7260 - learning_rate: 0.0078
# Epoch 116/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 74s 372ms/step - auc: 0.5836 - categorical_accuracy: 0.5408 - f1_score: 0.5408 - loss: 1.1878 - val_auc: 0.5115 - val_categorical_accuracy: 0.5207 - val_f1_score: 0.5207 - val_loss: 1.4810 - learning_rate: 0.0078
# Epoch 117/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - auc: 0.6536 - categorical_accuracy: 0.5788 - f1_score: 0.5788 - loss: 1.0050 - val_auc: 0.5861 - val_categorical_accuracy: 0.5966 - val_f1_score: 0.5966 - val_loss: 1.1988 - learning_rate: 0.0039
# Epoch 118/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - auc: 0.5005 - categorical_accuracy: 0.4813 - f1_score: 0.4813 - loss: 1.4768 - val_auc: 0.5679 - val_categorical_accuracy: 0.5846 - val_f1_score: 0.5846 - val_loss: 1.2824 - learning_rate: 0.0039
# Epoch 119/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 261ms/step - auc: 0.5187 - categorical_accuracy: 0.5000 - f1_score: 0.5000 - loss: 1.3495 - val_auc: 0.5083 - val_categorical_accuracy: 0.5103 - val_f1_score: 0.5103 - val_loss: 1.5144 - learning_rate: 0.0039
# Epoch 120/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 247ms/step - auc: 0.4713 - categorical_accuracy: 0.4521 - f1_score: 0.4521 - loss: 1.5146 - val_auc: 0.3570 - val_categorical_accuracy: 0.3826 - val_f1_score: 0.3826 - val_loss: 2.1066 - learning_rate: 0.0039
# Epoch 121/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 228ms/step - auc: 0.4819 - categorical_accuracy: 0.4622 - f1_score: 0.4622 - loss: 1.5563 - val_auc: 0.4418 - val_categorical_accuracy: 0.4693 - val_f1_score: 0.4693 - val_loss: 1.8394 - learning_rate: 0.0039
# Epoch 122/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 238ms/step - auc: 0.4970 - categorical_accuracy: 0.4770 - f1_score: 0.4770 - loss: 1.4559 - val_auc: 0.4035 - val_categorical_accuracy: 0.4296 - val_f1_score: 0.4296 - val_loss: 1.9213 - learning_rate: 0.0039
# Epoch 123/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 231ms/step - auc: 0.4874 - categorical_accuracy: 0.4666 - f1_score: 0.4666 - loss: 1.5664 - val_auc: 0.4835 - val_categorical_accuracy: 0.5032 - val_f1_score: 0.5032 - val_loss: 1.6099 - learning_rate: 0.0039
# Epoch 124/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 62s 314ms/step - auc: 0.6195 - categorical_accuracy: 0.5659 - f1_score: 0.5659 - loss: 1.0608 - val_auc: 0.4763 - val_categorical_accuracy: 0.4988 - val_f1_score: 0.4988 - val_loss: 1.5726 - learning_rate: 0.0039
# Epoch 125/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 152ms/step - auc: 0.6311 - categorical_accuracy: 0.5631 - f1_score: 0.5631 - loss: 1.0723 - val_auc: 0.4930 - val_categorical_accuracy: 0.5055 - val_f1_score: 0.5055 - val_loss: 1.5626 - learning_rate: 0.0039
# Epoch 126/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 203ms/step - auc: 0.4853 - categorical_accuracy: 0.4721 - f1_score: 0.4721 - loss: 1.5064 - val_auc: 0.5724 - val_categorical_accuracy: 0.5901 - val_f1_score: 0.5901 - val_loss: 1.2760 - learning_rate: 0.0039
# Epoch 127/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 233ms/step - auc: 0.5128 - categorical_accuracy: 0.4910 - f1_score: 0.4910 - loss: 1.4136 - val_auc: 0.5675 - val_categorical_accuracy: 0.5856 - val_f1_score: 0.5856 - val_loss: 1.2903 - learning_rate: 0.0020
# Epoch 128/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 245ms/step - auc: 0.4797 - categorical_accuracy: 0.4614 - f1_score: 0.4614 - loss: 1.4893 - val_auc: 0.5222 - val_categorical_accuracy: 0.5340 - val_f1_score: 0.5340 - val_loss: 1.4444 - learning_rate: 0.0020
# Epoch 129/500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 256ms/step - auc: 0.4835 - categorical_accuracy: 0.4647 - f1_score: 0.4647 - loss: 1.5410 - val_auc: 0.3619 - val_categorical_accuracy: 0.3857 - val_f1_score: 0.3857 - val_loss: 2.0550 - learning_rate: 0.0020
